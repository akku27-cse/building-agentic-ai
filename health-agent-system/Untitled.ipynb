# %%
# !pip install pyautogen
# Out:
# Requirement already satisfied: pyautogen in e:\apexiumwork\puphub-ai-ml\health-agent\myenv\lib\site-packages (0.10.0)
# Requirement already satisfied: autogen-agentchat>=0.6.4 in e:\apexiumwork\puphub-ai-ml\health-agent\myenv\lib\site-packages (from pyautogen) (0.7.5)
# Requirement already satisfied: autogen-core==0.7.5 in e:\apexiumwork\puphub-ai-ml\health-agent\myenv\lib\site-packages (from autogen-agentchat>=0.6.4->pyautogen) (0.7.5)
# Requirement already satisfied: jsonref~=1.1.0 in e:\apexiumwork\puphub-ai-ml\health-agent\myenv\lib\site-packages (from autogen-core==0.7.5->autogen-agentchat>=0.6.4->pyautogen) (1.1.0)
# Requirement already satisfied: opentelemetry-api>=1.34.1 in e:\apexiumwork\puphub-ai-ml\health-agent\myenv\lib\site-packages (from autogen-core==0.7.5->autogen-agentchat>=0.6.4->pyautogen) (1.34.1)
# Requirement already satisfied: pillow>=11.0.0 in e:\apexiumwork\puphub-ai-ml\health-agent\myenv\lib\site-packages (from autogen-core==0.7.5->autogen-agentchat>=0.6.4->pyautogen) (12.0.0)
# Requirement already satisfied: protobuf~=5.29.3 in e:\apexiumwork\puphub-ai-ml\health-agent\myenv\lib\site-packages (from autogen-core==0.7.5->autogen-agentchat>=0.6.4->pyautogen) (5.29.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.10.0 in e:\apexiumwork\puphub-ai-ml\health-agent\myenv\lib\site-packages (from autogen-core==0.7.5->autogen-agentchat>=0.6.4->pyautogen) (2.11.10)
# Requirement already satisfied: typing-extensions>=4.0.0 in e:\apexiumwork\puphub-ai-ml\health-agent\myenv\lib\site-packages (from autogen-core==0.7.5->autogen-agentchat>=0.6.4->pyautogen) (4.15.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in e:\apexiumwork\puphub-ai-ml\health-agent\myenv\lib\site-packages (from opentelemetry-api>=1.34.1->autogen-core==0.7.5->autogen-agentchat>=0.6.4->pyautogen) (8.7.1)
# Requirement already satisfied: annotated-types>=0.6.0 in e:\apexiumwork\puphub-ai-ml\health-agent\myenv\lib\site-packages (from pydantic<3.0.0,>=2.10.0->autogen-core==0.7.5->autogen-agentchat>=0.6.4->pyautogen) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in e:\apexiumwork\puphub-ai-ml\health-agent\myenv\lib\site-packages (from pydantic<3.0.0,>=2.10.0->autogen-core==0.7.5->autogen-agentchat>=0.6.4->pyautogen) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in e:\apexiumwork\puphub-ai-ml\health-agent\myenv\lib\site-packages (from pydantic<3.0.0,>=2.10.0->autogen-core==0.7.5->autogen-agentchat>=0.6.4->pyautogen) (0.4.2)
# Requirement already satisfied: zipp>=3.20 in e:\apexiumwork\puphub-ai-ml\health-agent\myenv\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.34.1->autogen-core==0.7.5->autogen-agentchat>=0.6.4->pyautogen) (3.23.0)
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from dotenv import load_dotenv
load_dotenv()

import os
print(os.getenv("GROQ_API_KEY"))
# Out:
# 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

# %%
from autogen import AssistantAgent, GroupChat, GroupChatManager

llm_config = {
    "config_list": [
        {
            "model": "llama3-70b-8192",
            "api_key": os.getenv("GROQ_API_KEY"),
            "base_url": "https://api.groq.com/openai/v1",
        }
    ],
    "temperature": 0.4,
}
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from autogen import AssistantAgent, GroupChat, GroupChatManager
#       3 llm_config = {
#       4     "config_list": [
#       5         {
#    (...)     11     "temperature": 0.4,
#      12 }
#
# ModuleNotFoundError: No module named 'autogen'

# %%
import autogen
print(autogen.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import autogen
#       2 print(autogen.__version__)
#
# ModuleNotFoundError: No module named 'autogen'
